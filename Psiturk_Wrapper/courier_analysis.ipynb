# %% [markdown]
# # Initial Setup

# %%
import sys
from sqlalchemy import create_engine, MetaData, Table
import json
import pandas as pd
import json
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

db_url = "mysql+pymysql://ckeane1:test_pass@localhost:3306/test_db"
# db_url = "mysql+pymysql://maint:strangle.explode.sprout.underfeed.yo-yo@psiturk.sas.upenn.edu:3306/psiturk"
table_name = 'courier'
data_column_name = 'datastring'
# boilerplace sqlalchemy setup
engine = create_engine(db_url)
metadata = MetaData()
metadata.bind = engine
table = Table(table_name, metadata, autoload=True)
# make a query and loop through
s = table.select()
rows = s.execute()

data = []
subject = []
#status codes of subjects who completed experiment
statuses = [3,4,5,7]
# if you have workers you wish to exclude, add them here
exclude = []
for row in rows:
    print(row)
    # only use subjects who completed experiment and aren't excluded
    if row['status'] in statuses and row['workerid'] not in exclude:
        data.append(row[data_column_name])
        subject.append(row['workerid'])

# Now we have all participant datastrings in a list.
# Let's make it a bit easier to work with:

# parse each participant's datastring as json object
# and take the 'data' sub-object
data = [json.loads(part)['data'] for part in data]
subject = []

# insert uniqueid field into trialdata in case it wasn't added
# in experiment:
# for part in data:
#     for record in part:
#         record['trialdata']['uniqueid'] = record['uniqueid']

# flatten nested list so we just have a list of the trialdata recorded
# each time psiturk.recordTrialData(trialdata) was called.
data = [record['trialdata'] for part in data for record in part]

# Put all subjects' trial data into a dataframe object from the
# 'pandas' python library: one option among many for analysis
data_frame = pd.DataFrame(data)
# data_frame
subject
# Out:
# ('debug360BZR:debugVAW85R', 'debugVAW85R', 'debug360BZR', 'debugJ3KCSC', '127.0.0.1', 'chrome', 'windows', 'en-US', 0, 0, '1.0', datetime.datetime(2021, 7, 27, 23, 36, 4), None, None, 0.0, 1, 'debug', '{"id": "debug360BZR:debugVAW85R", "condition": 0, "counterbalance": 0, "assignmentId": "debugVAW85R", "workerId": "debug360BZR", "hitId": "debugJ3KCS ... (4170243 characters truncated) ... indows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36", "mode": "debug", "status": "user data saved"}')
# ('debug9298IO:debugVP51II', 'debugVP51II', 'debug9298IO', 'debugYLURS0', '127.0.0.1', 'chrome', 'windows', 'en-US', 0, 0, '1.0', datetime.datetime(2021, 7, 28, 0, 10, 29), None, datetime.datetime(2021, 7, 28, 0, 50, 17), 0.0, 3, 'debug', '{"id": "debug9298IO:debugVP51II", "condition": 0, "counterbalance": 0, "assignmentId": "debugVP51II", "workerId": "debug9298IO", "hitId": "debugYLURS ... (7212935 characters truncated) ... indows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36", "mode": "debug", "status": "user data saved"}')
# []

# %%
# bring up the word pool
word_pool = []
with open("dbpool.txt", "r") as file:
    for line in file:
        word = line.strip()
        word = word.replace("_", " ")
        word_pool.append(word)

print(word_pool)
# Out:
# ['apron', 'bagels', 'baking soda', 'bread', 'cake', 'canolli', 'chocolate chips', 'cookies', 'croissant', 'doughnut', 'flour', 'muffins', 'roll', 'sugar', 'blow dryer', 'broom', 'brushes', 'cape', 'chair', 'comb', 'conditioner', 'curling iron', 'dustpan', 'hair spray', 'hair straightener', 'mirror', 'razor', 'scissors', 'shampoo', 'shaving cream', 'shears', 'soap', 'towels', 'trash can', 'back pack', 'bell', 'breaks', 'chain', 'decals', 'handle bar', 'helmet', 'light', 'locks', 'paint', 'pump', 'reflectors', 'tires', 'training wheels', 'water bottle', 'chocolate', 'coffee', 'cream', 'cups', 'fruit', 'half-and-half', 'hot chocolate', 'milk', 'napkins', 'pastries', 'scones', 'straws', 'sweet-n-low', 'syrup', 'tea', 'dress', 'hangers', 'head band', 'jacket', 'jeans', 'laundry bag', 'pants', 'pins', 'purse', 'robe', 'sandals', 'scarf', 'shirts', 'shoes', 'shorts', 'skirt', 'socks', 'stockings', 'suit', 'sweatshirt', 'swim suits', 'tank top', 'tie', 'underwear', 'vest', 'computer', 'cotton balls', "dentist's chair", 'drill', 'floss', 'fluoride', 'lollipops', 'mouthwash', 'pick', 'retainer', 'syringe', 'toothbrush', 'toothpaste', 'x-ray machine', 'canvas', 'confetti', 'construction paper', 'embroidery', 'fabric', 'glue', 'markers', 'needle', 'pastels', 'popsicle sticks', 'ribbon', 'saw', 'stickers', 'string', 'styrofoam', 'tape', 'thread', 'tracing paper', 'yarn', 'apples', 'asparagus', 'bags', 'beans', 'blueberries', 'bottled water', 'boxes', 'cash register', 'cereal', 'cold cuts', 'containers', 'eggs', 'grapes', 'ham', 'jello', 'juice', 'kiwi', 'oatmeal', 'orange', 'orange juice', 'pears', 'peas', 'produce', 'raisins', 'raspberries', 'shopping cart', 'strawberries', 'yogurt', 'adhesive', 'amethyst', 'beads', 'bracelet', 'clamp', 'diamond', 'earrings', 'emerald', 'gold', 'hair clip', 'necklace', 'pearls', 'pendant', 'platinum', 'rings', 'rubies', 'sapphire', 'silver', 'soldering iron', 'tweezers', 'watch', 'cards', 'chrysanthemum', 'daffodils', 'daisies', 'ferns', 'fertilizer', 'flowers', 'hose', 'lilies', 'mop', 'orchids', 'peonies', 'plastic wrap', 'pots', 'roses', 'seeds', 'soil', 'sunflower', 'tulips', 'vase', 'water', 'watering can', 'wrapping paper', 'bolts', 'hammer', 'level', 'lumber', 'nailgun', 'nails', 'nuts', 'pipes', 'pliers', 'sandpaper', 'screen', 'screwdriver', 'screws', 'spackle', 'tape measure', 'tile', 'vacuum cleaner', 'washers', 'wheel barrow', 'wire', 'wood', 'wrench', 'barbells', 'baseball bat', 'bench', 'boxing gloves', 'chalk', 'dumbells', 'exercise bike', 'floor mat', 'hand sanitizer', 'jump rope', 'kickboard', 'locker', 'medicine ball', 'protein shakes', 'punching bag', 'rope', 'scale', 'stair master', 'step', 'television', 'treadmill', 'volleyball', 'anchovies', 'basil', 'dough', 'garlic', 'menu', 'mozzarella', 'mushrooms', 'olives', 'oregano', 'oven', 'pepperoni', 'pizza box', 'spatula', 'spinach', 'tomato sauce', 'bird', 'bunny', 'cage', 'canary', 'cat', 'chew toy', 'collar', 'dog', 'ferret', 'fish bowl', 'gerbil', 'guinea pig', 'hamster', 'leash', 'mice', 'parrot', 'python', 'rat', 'turtle', 'wood shavings', '8-track', 'albums', 'amplifier', 'bass', 'cd player', 'cds', 'drum set', 'dvds', 'flute', 'guitar', 'guitar strings', 'harmonica', 'keyboard', 'lava lamp', 'piano', 'recorder', 'records', 'saxophone', 'sheet music', 'speakers', 'stereo', 'tapes', 'trombone', 'trumpet', 'violin', 'xylophone', 'advil', 'allergy medicine', 'aspirin', 'band aids', 'bandages', 'contact solution', 'cough syrup', 'ear plugs', 'eye drops', 'gauze', 'hair brush', 'lotion', 'nose spray', 'ointment', 'pills', 'q-tips', 'thermometers', 'tissues', 'tylenol', 'vitamins', 'action figures', 'blocks', 'board game', 'checkers', 'doll', 'dollhouse', 'hula hoop', 'karaoke machine', 'legos', 'puppets', 'sled', 'slinkie', 'stuffed animal', 'swing set', 'train set', 'video games', 'water gun', 'yoyo']

# %% [markdown]
# ## Spell checker function

# %%
import Levenshtein as lev

def spellChecker(word_pool, word, threshold):
    closest_word = ""
    closest_score = 0.0

    for i in range(len(word_pool)):
        similarity = lev.ratio(word_pool[i], word)
        if similarity >= closest_score:
            closest_score = similarity
            closest_word = word_pool[i]
    return closest_word

spellChecker(word_pool, "dumb bells", 0.7)
# Out:
# 'dumbells'

# %% [markdown]
# ## Attemp to parse data

# %%
# create a dataframe with columns specified
column_names = ["subject", "trial", "type", "store", "store mappings", "posx", "posz", "roty", "item", "serialpos", "rectime", "recalled", "intrusion", "time"]
df = pd.DataFrame(columns = column_names)

for row in range(len(data_frame)-2):
    report = data_frame[0][row]
    report_dict = json.loads(report)

    # player position information
    if report_dict["type"] == "PlayerTransform":
        transform_data = report_dict["data"]
# Out:
# {'type': 'loadScene', 'data': {'sceneName': 'MainGame'}, 'time': 1627520894830.3}
# {'type': 'versions', 'data': {'UnityEPL version': '1.0', 'Experiment version': 'v4.1.2online', 'Logfile version': '1'}, 'time': 1627520894830.4}
# {'type': 'press any key prompt', 'data': {'displayed text': 'Press any key to play movie.'}, 'time': 1627520894990.2}
# {'type': 'PlayerTransform', 'data': {'positionX': -1.07288361e-06, 'positionY': 0.0, 'positionZ': -1.53477231e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520895072}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.026558e-06, 'positionY': 0.0, 'positionZ': -2.89901436e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520895239}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520895406}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520895573}
# {'type': 'text display cleared', 'data': {}, 'time': 1627520895723.2}
# {'type': 'key/mouse press/release', 'data': {'key code': 32, 'is pressed': True}, 'time': 1627520895723}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520895755}
# {'type': 'key/mouse press/release', 'data': {'key code': 32, 'is pressed': False}, 'time': 1627520895823}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520895922}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520896089}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520896256}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520896422}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520896588}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520896755}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520896922}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520897088}
# {'type': 'repeat video prompt', 'data': {'displayed text': 'Press Y to continue to the first delivery day, \n Press N to replay instructional video.'}, 'time': 1627520897207.3}
# {'type': 'key/mouse press/release', 'data': {'key code': 32, 'is pressed': True}, 'time': 1627520897206}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520897255}
# {'type': 'key/mouse press/release', 'data': {'key code': 32, 'is pressed': False}, 'time': 1627520897322}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520897422}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520897588}
# {'type': 'text display cleared', 'data': {}, 'time': 1627520897639.4}
# {'type': 'instruction message displayed', 'data': {'message name': 'delivery restart message en'}, 'time': 1627520897639.5}
# {'type': 'key/mouse press/release', 'data': {'key code': 121, 'is pressed': True}, 'time': 1627520897639}
# {'type': 'key/mouse press/release', 'data': {'key code': 121, 'is pressed': False}, 'time': 1627520897739}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520897755}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520897922}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520898088}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520898255}
# {'type': 'instruction message cleared', 'data': {'message name': 'delivery restart message en'}, 'time': 1627520898355.9}
# {'type': 'store mappings', 'data': {'bakery': 'pet store', 'pet store position X': -60.0, 'pet store position Y': 0.0, 'pet store position Z': -11.5, 'barber_shop': 'bike shop', 'bike shop position X': 14.55, 'bike shop position Y': -0.04, 'bike shop position Z': -58.79, 'bike_shop': 'music store', 'music store position X': 32.2, 'music store position Y': 0.33, 'music store position Z': -60.9, 'cafe': 'gym', 'gym position X': 62.34, 'gym position Y': 0.0, 'gym position Z': -33.51, 'clothing_store': 'toy store', 'toy store position X': 14.49, 'toy store position Y': 2.27, 'toy store position Z': -33.74, 'dentist': 'pizzeria', 'pizzeria position X': 59.29, 'pizzeria position Y': 4.65, 'pizzeria position Z': -9.16, 'craft_shop': 'hardware store', 'hardware store position X': 26.49, 'hardware store position Y': 0.58, 'hardware store position Z': 16.95, 'grocery_store': 'clothing store', 'clothing store position X': 35.4, 'clothing store position Y': 0.0, 'clothing store position Z': -33.11, 'jewelry_store': 'florist', 'florist position X': -29.57, 'florist position Y': 1.89, 'florist position Z': -37.24, 'florist': 'jewelry store', 'jewelry store position X': 35.06, 'jewelry store position Y': 0.0, 'jewelry store position Z': 26.66, 'hardware_store': 'pharmacy', 'pharmacy position X': -14.25, 'pharmacy position Y': 0.0, 'pharmacy position Z': -12.89, 'gym': 'barber shop', 'barber shop position X': -9.09, 'barber shop position Y': 0.0, 'barber shop position Z': 17.86, 'pizzeria': 'cafe', 'cafe position X': 58.31, 'cafe position Y': 4.05, 'cafe position Z': 27.93, 'pet_store': 'craft shop', 'craft shop position X': -31.82, 'craft shop position Y': 4.7, 'craft shop position Z': 55.71, 'music_store': 'grocery store', 'grocery store position X': 36.74, 'grocery store position Y': -1.91, 'grocery store position Z': 59.06, 'pharmacy': 'dentist', 'dentist position X': -38.95, 'dentist position Y': 0.0, 'dentist position Z': -61.87, 'toy_store': 'bakery', 'bakery position X': -3.07, 'bakery position Y': 0.0, 'bakery position Z': -58.51}, 'time': 1627520898356.1}
# {'type': 'start delivery', 'data': {'trial number': 0}, 'time': 1627520898358.1}
# {'type': 'start pointing', 'data': {'start direction': 144.0, 'store': 'florist'}, 'time': 1627520898360.4}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520898356}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520899162}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520899207}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520899387}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520899587}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520899754}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520899920}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520900087}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520900257}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520900420}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520900587}
# {'type': 'key/mouse press/release', 'data': {'key code': 276, 'is pressed': True}, 'time': 1627520900673}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520900753}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520900959}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520901120}
# {'type': 'key/mouse press/release', 'data': {'key code': 276, 'is pressed': False}, 'time': 1627520901204}
# {'type': 'key/mouse press/release', 'data': {'key code': 275, 'is pressed': True}, 'time': 1627520901254}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520901286}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520901453}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520901620}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520901786}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520901953}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520902119}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520902286}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520902453}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520902619}
# {'type': 'key/mouse press/release', 'data': {'key code': 275, 'is pressed': False}, 'time': 1627520902720}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520902786}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520902952}
# {'type': 'end pointing', 'data': {'correct direction (degrees)': 213.663788, 'pointed direction (degrees)': 205.241714}, 'time': 1627520902986.5}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520902986}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520903119}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520903120}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520903286}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520903452}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520903619}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520903636}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520903743}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520903803}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520903985}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520904103}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520904152}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520904219}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520904318}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520904353}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520904469}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520904485}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520904569}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520904652}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520904669}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520904786}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520904819}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520904886}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520904969}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520904985}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520905086}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520905152}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520905153}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520905253}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520905318}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520905336}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520905436}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520905485}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520905486}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520905586}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520905651}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520905685}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520905786}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520905818}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520905985}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520906151}
# {'type': 'pointer message cleared', 'data': {}, 'time': 1627520906269}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520906269}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520906318}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520906402}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520906484}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': True}, 'time': 1627520906618}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.74181366e-06, 'positionY': 0.0, 'positionZ': -3.922196e-12, 'rotationX': 0.0, 'rotationY': 270.0, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520906651}
# {'type': 'key/mouse press/release', 'data': {'key code': 115, 'is pressed': True}, 'time': 1627520906802}
# {'type': 'PlayerTransform', 'data': {'positionX': 0.0151336947, 'positionY': 0.0, 'positionZ': 0.0006438056, 'rotationX': 0.0, 'rotationY': 267.3129, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520906818}
# {'type': 'PlayerTransform', 'data': {'positionX': 0.384996861, 'positionY': 5.96046448e-07, 'positionZ': 0.06099027, 'rotationX': 0.0, 'rotationY': 256.8781, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520906984}
# {'type': 'PlayerTransform', 'data': {'positionX': 1.20402324, 'positionY': 1.07288361e-06, 'positionZ': 0.360350966, 'rotationX': 0.0, 'rotationY': 245.230118, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520907151}
# {'type': 'key/mouse press/release', 'data': {'key code': 115, 'is pressed': False}, 'time': 1627520907218}
# {'type': 'PlayerTransform', 'data': {'positionX': 2.08803439, 'positionY': 1.90734863e-06, 'positionZ': 0.884585, 'rotationX': 0.0, 'rotationY': 233.561127, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520907317}
# {'type': 'key/mouse press/release', 'data': {'key code': 119, 'is pressed': True}, 'time': 1627520907336}
# {'type': 'PlayerTransform', 'data': {'positionX': 1.84055924, 'positionY': 2.38418579e-06, 'positionZ': 0.634109259, 'rotationX': 0.0, 'rotationY': 221.4091, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520907491}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': False}, 'time': 1627520907559}
# {'type': 'PlayerTransform', 'data': {'positionX': 1.19365013, 'positionY': 1.78813934e-06, 'positionZ': -0.3014107, 'rotationX': 0.0, 'rotationY': 211.0291, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520907665}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': True}, 'time': 1627520907793}
# {'type': 'PlayerTransform', 'data': {'positionX': 0.207797557, 'positionY': 2.14576721e-06, 'positionZ': -2.0340898, 'rotationX': 0.0, 'rotationY': 209.055084, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520907844}
# {'type': 'PlayerTransform', 'data': {'positionX': -0.663181961, 'positionY': 2.503395e-06, 'positionZ': -3.927762, 'rotationX': 0.0, 'rotationY': 200.325027, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520908005}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': False}, 'time': 1627520908118}
# {'type': 'PlayerTransform', 'data': {'positionX': -1.17961037, 'positionY': 2.503395e-06, 'positionZ': -5.9689045, 'rotationX': 0.0, 'rotationY': 189.553192, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520908167}
# {'type': 'PlayerTransform', 'data': {'positionX': -1.41241872, 'positionY': 2.503395e-06, 'positionZ': -8.122957, 'rotationX': 0.0, 'rotationY': 185.1768, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520908334}
# {'type': 'PlayerTransform', 'data': {'positionX': -1.60783863, 'positionY': 2.503395e-06, 'positionZ': -10.2799225, 'rotationX': 0.0, 'rotationY': 185.1768, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520908500}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': True}, 'time': 1627520908634}
# {'type': 'PlayerTransform', 'data': {'positionX': -1.80325854, 'positionY': 2.503395e-06, 'positionZ': -12.4368877, 'rotationX': 0.0, 'rotationY': 185.1768, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520908667}
# {'type': 'PlayerTransform', 'data': {'positionX': -1.98323631, 'positionY': 2.503395e-06, 'positionZ': -14.59373, 'rotationX': 0.0, 'rotationY': 183.0824, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520908833}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': False}, 'time': 1627520908851}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.0513742, 'positionY': 3.93390656e-06, 'positionZ': -16.7610455, 'rotationX': 0.0, 'rotationY': 181.736084, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520909000}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': True}, 'time': 1627520909101}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.11694884, 'positionY': 6.07967377e-06, 'positionZ': -18.924551, 'rotationX': 0.0, 'rotationY': 181.736084, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520909167}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': False}, 'time': 1627520909284}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.170503, 'positionY': 7.27176666e-06, 'positionZ': -21.0896549, 'rotationX': 0.0, 'rotationY': 181.0978, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520909333}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.21197248, 'positionY': 7.27176666e-06, 'positionZ': -23.25376, 'rotationX': 0.0, 'rotationY': 181.0978, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520909500}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.25349116, 'positionY': 7.27176666e-06, 'positionZ': -25.42047, 'rotationX': 0.0, 'rotationY': 181.0978, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520909666}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': True}, 'time': 1627520909800}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.29498553, 'positionY': 7.27176666e-06, 'positionZ': -27.5858746, 'rotationX': 0.0, 'rotationY': 181.0978, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520909833}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.31225634, 'positionY': 7.27176666e-06, 'positionZ': -29.7513218, 'rotationX': 0.0, 'rotationY': 178.416336, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520909999}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': False}, 'time': 1627520910017}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.20392966, 'positionY': 7.27176666e-06, 'positionZ': -31.917, 'rotationX': 0.0, 'rotationY': 177.0721, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520910166}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.09343529, 'positionY': 7.27176666e-06, 'positionZ': -34.0773735, 'rotationX': 0.0, 'rotationY': 177.0721, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520910333}
# {'type': 'key/mouse press/release', 'data': {'key code': 100, 'is pressed': True}, 'time': 1627520910384}
# {'type': 'PlayerTransform', 'data': {'positionX': -1.98280787, 'positionY': 7.27176666e-06, 'positionZ': -36.2403526, 'rotationX': 0.0, 'rotationY': 177.0721, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520910499}
# {'type': 'PlayerTransform', 'data': {'positionX': -1.99777663, 'positionY': 7.27176666e-06, 'positionZ': -38.406868, 'rotationX': 0.0, 'rotationY': 184.425247, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520910666}
# {'type': 'PlayerTransform', 'data': {'positionX': -2.40145159, 'positionY': 7.033348e-06, 'positionZ': -40.5283165, 'rotationX': 0.0, 'rotationY': 196.015152, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520910833}
# {'type': 'PlayerTransform', 'data': {'positionX': -3.22744417, 'positionY': 7.15255737e-06, 'positionZ': -42.52785, 'rotationX': 0.0, 'rotationY': 207.684143, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520910999}
# {'type': 'PlayerTransform', 'data': {'positionX': -4.439547, 'positionY': 6.854534e-06, 'positionZ': -44.3182449, 'rotationX': 0.0, 'rotationY': 219.346161, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520911166}
# {'type': 'key/mouse press/release', 'data': {'key code': 119, 'is pressed': False}, 'time': 1627520911200}
# {'type': 'PlayerTransform', 'data': {'positionX': -5.62673044, 'positionY': 8.165836e-06, 'positionZ': -45.49969, 'rotationX': 0.0, 'rotationY': 231.008163, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520911332}
# {'type': 'key/mouse press/release', 'data': {'key code': 119, 'is pressed': True}, 'time': 1627520911383}
# {'type': 'PlayerTransform', 'data': {'positionX': -6.679479, 'positionY': 8.523464e-06, 'positionZ': -46.16007, 'rotationX': 0.0, 'rotationY': 242.663177, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520911499}
# {'type': 'PlayerTransform', 'data': {'positionX': -8.486209, 'positionY': 9.775162e-06, 'positionZ': -46.839344, 'rotationX': 0.0, 'rotationY': 254.318161, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520911665}
# {'type': 'key/mouse press/release', 'data': {'key code': 100, 'is pressed': False}, 'time': 1627520911716}
# {'type': 'PlayerTransform', 'data': {'positionX': -10.6182775, 'positionY': 1.09672546e-05, 'positionZ': -47.2138634, 'rotationX': 0.0, 'rotationY': 263.888184, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520911832}
# {'type': 'key/mouse press/release', 'data': {'key code': 100, 'is pressed': True}, 'time': 1627520911933}
# {'type': 'PlayerTransform', 'data': {'positionX': -12.7770195, 'positionY': 1.08480453e-05, 'positionZ': -47.38656, 'rotationX': 0.0, 'rotationY': 267.034241, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520911999}
# {'type': 'key/mouse press/release', 'data': {'key code': 100, 'is pressed': False}, 'time': 1627520912117}
# {'type': 'PlayerTransform', 'data': {'positionX': -14.9404564, 'positionY': 1.12056732e-05, 'positionZ': -47.3134346, 'rotationX': 0.0, 'rotationY': 276.078552, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520912165}
# {'type': 'PlayerTransform', 'data': {'positionX': -17.0829582, 'positionY': 1.14440918e-05, 'positionZ': -46.99756, 'rotationX': 0.0, 'rotationY': 278.7598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520912332}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': True}, 'time': 1627520912400}
# {'type': 'PlayerTransform', 'data': {'positionX': -19.22221, 'positionY': 1.14440918e-05, 'positionZ': -46.66793, 'rotationX': 0.0, 'rotationY': 278.7598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520912499}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': False}, 'time': 1627520912616}
# {'type': 'PlayerTransform', 'data': {'positionX': -21.3678513, 'positionY': 1.15633011e-05, 'positionZ': -46.3750572, 'rotationX': 0.0, 'rotationY': 276.786, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520912665}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': True}, 'time': 1627520912816}
# {'type': 'PlayerTransform', 'data': {'positionX': -23.5184822, 'positionY': 1.15633011e-05, 'positionZ': -46.11915, 'rotationX': 0.0, 'rotationY': 276.786, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520912832}
# {'type': 'PlayerTransform', 'data': {'positionX': -25.6696568, 'positionY': 1.15633011e-05, 'positionZ': -45.8680153, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520912998}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': False}, 'time': 1627520912999}
# {'type': 'key/mouse press/release', 'data': {'key code': 119, 'is pressed': False}, 'time': 1627520913099}
# {'type': 'PlayerTransform', 'data': {'positionX': -27.6641464, 'positionY': 1.26361847e-05, 'positionZ': -45.6532059, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520913165}
# {'type': 'object presentation begins', 'data': {'trial number': 0, 'item name': 'fertilizer', 'store value': -1, 'point condition': 1, 'store name': 'florist', 'serial position': 1, 'player position': '(-28.2, 0.0, -45.6)', 'store position': '(-29.6, 1.9, -37.2)'}, 'time': 1627520913235.3}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.3589859e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520913332}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': True}, 'time': 1627520913433}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.45435333e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520913498}
# {'type': 'key/mouse press/release', 'data': {'key code': 97, 'is pressed': False}, 'time': 1627520913566}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520913665}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520913832}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520913998}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520914165}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520914331}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520914498}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520914665}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520914831}
# {'type': 'audio presentation finished', 'data': {}, 'time': 1627520914949.4}
# {'type': 'start pointing', 'data': {'start direction': 88.0, 'store': 'hardware store'}, 'time': 1627520914950.2}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520914998}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520915164}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520915331}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520915497}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520915664}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520915831}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520915997}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520916164}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520916331}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520916497}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520916663}
# {'type': 'key/mouse press/release', 'data': {'key code': 276, 'is pressed': True}, 'time': 1627520916665}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520916830}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520916997}
# {'type': 'key/mouse press/release', 'data': {'key code': 276, 'is pressed': False}, 'time': 1627520917048}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520917163}
# {'type': 'key/mouse press/release', 'data': {'key code': 276, 'is pressed': True}, 'time': 1627520917264}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520917330}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520917496}
# {'type': 'key/mouse press/release', 'data': {'key code': 276, 'is pressed': False}, 'time': 1627520917580}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520917663}
# {'type': 'end pointing', 'data': {'correct direction (degrees)': 43.7729721, 'pointed direction (degrees)': 44.7769966}, 'time': 1627520917714.2}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520917714}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520917830}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520917864}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520917996}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520918163}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520918329}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520918430}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520918496}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520918580}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520918647}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520918662}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520918780}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520918829}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520918830}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520918947}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520918996}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520918997}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520919114}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520919162}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520919180}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520919297}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520919329}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520919346}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520919464}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520919496}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520919513}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520919646}
# {'type': 'PlayerTransform', 'data': {'positionX': -28.2023525, 'positionY': 1.53779984e-05, 'positionZ': -45.5952377, 'rotationX': 0.0, 'rotationY': 276.147369, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627520919662}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': True}, 'time': 1627520919696}
# {'type': 'key/mouse press/release', 'data': {'key code': 120, 'is pressed': False}, 'time': 1627520919813}
# ...
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523246933}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523247100}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523247266}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523247466}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523247632}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523247799}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523247965}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523248132}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523248299}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523248465}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523248632}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523248798}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523248965}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523249132}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523249298}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523249465}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523249632}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523249798}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523249965}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523250131}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523250298}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523250465}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523250631}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523250798}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523250965}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523251131}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523251298}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523251464}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523251631}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523251798}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523251964}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523252131}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523252298}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523252497}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523252664}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523252830}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523252997}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523253163}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523253330}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523253496}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523253663}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523253830}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523253996}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523254163}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523254329}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523254496}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523254663}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523254829}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523254996}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523255162}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523255329}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523255496}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523255662}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523255829}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523255996}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523256162}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523256329}
# {'type': 'endfinal object recalltyping', 'data': {'trial number': -999}, 'time': 1627523256396.9}
# {'type': 'text display cleared', 'data': {}, 'time': 1627523256397.1}
# {'type': 'Sound played', 'data': {'sound name': 'low beep', 'sound duration': '0.769864'}, 'time': 1627523256398.9}
# {'type': 'end final recall', 'data': {}, 'time': 1627523256398.9}
# {'type': 'end text', 'data': {'displayed text': 'Thank you for being a great delivery person! Your cumulative score is: +4.64'}, 'time': 1627523256399}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523256496}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523256662}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523256829}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523256995}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523257162}
# {'type': 'PlayerTransform', 'data': {'positionX': -31.9577675, 'positionY': 0.00106203556, 'positionZ': 49.8652573, 'rotationX': 0.0, 'rotationY': 89.22598, 'rotationZ': 0.0, 'reportID': 'Player', 'objectName': 'Player'}, 'time': 1627523257329}

# %% [markdown]
# # **Participant-level Analysis**

# %% [markdown]
# # Total length of the experiment

# %%
start = data_frame[0][0]
start_dict = json.loads(start)
start_time = start_dict["time"]

end = data_frame[0][len(data_frame)-3]
end_dict = json.loads(end)
end_time = end_dict["time"]

np.round((end_time - start_time) / 1000 / 60, 1)
# Out:
# 39.4

# %% [markdown]
# # Duration of each delivery day (navigation only)

# %%
delivery_start = []
delivery_end = []

for row in range(len(data_frame)-2):
    report = data_frame[0][row]
    report_dict = json.loads(report)

    if report_dict["type"] == "start delivery":
        delivery_start.append(report_dict["time"])

    if report_dict["type"] == "end delivery": # "free recall started" 
        delivery_end.append(report_dict["time"])

delivery_start = np.array(delivery_start)
delivery_end = np.array(delivery_end)

delivery_time = np.round((delivery_end - delivery_start) / 1000 / 60, 1)
delivery_time_string = "Navigation time for each delivery day\n"
for i in range(len(delivery_time)):
    delivery_time_string += "Day {}: {} min, ".format(i, delivery_time[i])

print(delivery_time_string)
print("Average delivery time: {} min".format(np.mean(delivery_time)))
# Out:
# Navigation time for each delivery day
# Day 0: 3.8 min, Day 1: 3.9 min, Day 2: 4.0 min, Day 3: 3.5 min, Day 4: 4.0 min,
# Average delivery time: 3.84 min

# %% [markdown]
# # Delivery day data (free recall)

# %%
delivery_days = [0,1,2,3,4]
total_free_recall_list = []
recalled_time = []

for day in delivery_days:
    item_list = []
    item_time = []
    free_recall_list = []
    free_recall_time = []

    # loop through the data...
    for row in range(len(data_frame)-2):
        # convert the string format into json format
        report = data_frame[0][row]
        # convert_to_json = report.replace("'", "\"")
        report_dict = json.loads(report)

        # only look at "data" portion for now
        data_dict = report_dict["data"]
    
        # pull out specific day info
        if (data_dict.get("trial number") != None) and (data_dict["trial number"] == day):
            
            # list of items that are delivered in a delivery day
            item = data_dict.get("item name")
            if item != None:
                item_list.append(item)
                item_time.append(report_dict["time"])

            # list of items that are recalled during free recall task
            item_recalled = data_dict.get("typed response")
            is_free_recall = data_dict.get("store displayed") == None
            if is_free_recall and (item_recalled != None):
                item_recalled_spellchecked = spellChecker(word_pool, item_recalled, 0.7)
                free_recall_list.append(item_recalled_spellchecked)
                free_recall_time.append(report_dict["time"])

    # make first instance time as 0 and subtract the rest
    item_time[:] = [np.round((item - item_time[0]) / 1000, 1) for item in item_time]
    free_recall_time[:] = [np.round((time - free_recall_time[0]) / 1000, 1) for time in free_recall_time]
    recalled_time.append(free_recall_time)

    # create a pd dataframe
    free_recall_dict = {"list of item" : item_list, "time displayed" : item_time,
                   "items recalled" : free_recall_list, "time recalled": free_recall_time}
    free_recall_df = pd.DataFrame.from_dict(free_recall_dict, orient="index")
    total_free_recall_list.append(free_recall_df)

# %%
# free recall data for each delivery day (0~4 days)
total_free_recall_df = pd.concat(total_free_recall_list, keys=["Day1", "Day2", "Day3", "Day4", "Day5"])
total_free_recall_df
# Out:
#                                0               1               2          3   \
# Day1 list of item      fertilizer           bolts     blueberries  amplifier
#      time displayed           0.0            16.9            32.3       53.2
#      items recalled          cups     blueberries    baseball bat       menu
#      time recalled            0.0             2.2             4.5        5.4
# Day2 list of item      nose spray             ham       saxophone  anchovies
#      time displayed           0.0            21.1            41.5       54.7
#      items recalled     fish bowl       back pack       anchovies  chocolate
#      time recalled            0.0             1.8             3.6        5.8
# Day3 list of item         peonies            milk         muffins     grapes
#      time displayed           0.0            25.8            46.4       67.3
#      items recalled       sandals         muffins      handle bar    oregano
#      time recalled            0.0             1.7             5.8       11.3
# Day4 list of item          screws       asparagus       pizza box     scones
#      time displayed           0.0            13.6            26.9       40.2
#      items recalled     asparagus       pizza box           apron   recorder
#      time recalled            0.0             3.1             4.4       11.5
# Day5 list of item       ear plugs            cage  action figures  head band
#      time displayed           0.0            18.5            38.0       55.9
#      items recalled  cotton balls  action figures         canolli      pipes
#      time recalled            0.0             2.0             5.4        8.7
#
#                            4               5                6           7   \
# Day1 list of item        menu    baseball bat            drill        cups
#      time displayed      69.3            81.6             98.8       121.1
#      items recalled       tie       amplifier  training wheels  fertilizer
#      time recalled        6.2             8.3             12.9        15.4
# Day2 list of item    checkers    tape measure             comb   chocolate
#      time displayed      71.5            86.2            100.6       120.8
#      items recalled       ham        sapphire       nose spray      shorts
#      time recalled        9.9            12.0             14.1        19.5
# Day3 list of item     sandals         oregano       handle bar     diamond
#      time displayed      83.4            95.3            109.5       135.2
#      items recalled      milk          grapes        mouthwash     peonies
#      time recalled       13.2            14.9             19.4        22.1
# Day4 list of item       apron        recorder           decals     hangers
#      time displayed      59.4            73.7             84.8        98.7
#      items recalled    thread  protein shakes   protein shakes        None
#      time recalled       17.3            56.4             65.5        None
# Day5 list of item     canolli           syrup            pipes      violin
#      time displayed      72.4            94.7            108.0       123.6
#      items recalled   shampoo            bags   hand sanitizer   head band
#      time recalled       10.6            14.0             19.3        23.4
#
#                               8             9           10               11
# Day1 list of item          bread      scissors         tie  training wheels
#      time displayed        138.9         158.3       178.2            193.0
#      items recalled        drill         bolts    scissors             None
#      time recalled          16.9          17.9        24.3             None
# Day2 list of item      fish bowl     back pack    sapphire           shorts
#      time displayed        147.8         165.5       183.2            199.7
#      items recalled       shorts      checkers        None             None
#      time recalled          30.4          56.0        None             None
# Day3 list of item         guitar        towels   mouthwash       volleyball
#      time displayed        155.9         171.7       188.7            209.0
#      items recalled      diamond        towels  volleyball             None
#      time recalled          25.0          27.5        56.1             None
# Day4 list of item    cough syrup        thread        bird   protein shakes
#      time displayed        119.6         135.2       151.4            174.6
#      items recalled         None          None        None             None
#      time recalled          None          None        None             None
# Day5 list of item        shampoo  cotton balls        bags   hand sanitizer
#      time displayed        141.9         160.1       187.2            203.0
#      items recalled       violin          None        None             None
#      time recalled          31.0          None        None             None

# %% [markdown]
# # Serial Position Curve & Probability of First Recall

# %%
positions = np.arange(1,13)
prob_list = []

for pos in range(len(total_free_recall_df.columns)):
    words = total_free_recall_df.iloc[0:20:4][pos].values  
    recalled_words = total_free_recall_df.iloc[2:22:4].values.flatten()

    num_recalled = 0
    for word in words:
        if word in recalled_words:
            num_recalled += 1
    
    prob_list.append(round(num_recalled / len(words) * 100,2))

fig = plt.figure(figsize=(10, 6)); ax = plt.subplot(111)
ax.plot(positions, prob_list, "r")
plt.xticks(positions)
plt.xlabel('Serial Position'); plt.ylabel('Recall Probability(%)')
plt.show()

for pos in range(len(total_free_recall_df.columns)):
    recalled_words = total_free_recall_df[2:22:4][pos].values
    print(recalled_words)
# Out:
# ['cups' 'fish bowl' 'sandals' 'asparagus' 'cotton balls']
# ['blueberries' 'back pack' 'muffins' 'pizza box' 'action figures']
# ['baseball bat' 'anchovies' 'handle bar' 'apron' 'canolli']
# ['menu' 'chocolate' 'oregano' 'recorder' 'pipes']
# ['tie' 'ham' 'milk' 'thread' 'shampoo']
# ['amplifier' 'sapphire' 'grapes' 'protein shakes' 'bags']
# ['training wheels' 'nose spray' 'mouthwash' 'protein shakes'
#  'hand sanitizer']
# ['fertilizer' 'shorts' 'peonies' None 'head band']
# ['drill' 'shorts' 'diamond' None 'violin']
# ['bolts' 'checkers' 'towels' None None]
# ['scissors' None 'volleyball' None None]
# [None None None None None]

# %% [markdown]
# # Temporal Lag-CRP

# %%
# get the transitions for all delivery days
days = [0,1,2,3,4]
transitions_list = []

# Loop throught each list
for day in days:
    serial_pos_dict = {}
    word_list = total_free_recall_df.iloc[day*4].values
    rec_word_list = total_free_recall_df.iloc[day*4+2].dropna().values

    # manually store serial position information in dictionary (for now)
    # should be easy look-up after I implement parser for Courier Online data
    for i in range(len(word_list)):
        serial_pos_dict[word_list[i]] = i + 1
    
    rec_serial_positions = []
    for i in range(len(rec_word_list)):
        rec_word = rec_word_list[i]
        
        # remove intrusions
        if rec_word in word_list:
            rec_serial_positions.append(serial_pos_dict[rec_word])

    # remove possible redundancies
    actual_transitions = []
    [actual_transitions.append(pos) for pos in rec_serial_positions if pos not in actual_transitions]
    transitions_list.append(actual_transitions)

transitions_list
# Out:
# [[8, 3, 6, 5, 11, 4, 12, 1, 7, 2, 10],
#  [9, 10, 4, 8, 2, 11, 1, 12, 5],
#  [5, 3, 7, 6, 2, 4, 11, 1, 8, 10, 12],
#  [2, 3, 5, 6, 10, 12],
#  [10, 3, 5, 7, 9, 11, 12, 4, 8]]

# %%
# calculate Lag-CRP

days = [0,1,2,3,4]
all_actual_lags = []
all_possible_lags = []

for day in days:
    transitions = transitions_list[day]

    actual_lag = []
    # there are 12 words per list
    possible_transitions = np.arange(1,13)
    possible_lags = []

    for j in range(len(transitions)):
        # calculate lag
        if (j != 0):
            lag = transitions[j] - transitions[j-1]
            all_actual_lags.append(lag)

        # remove current serial position from the list
        possible_transitions = possible_transitions[possible_transitions != transitions[j]]
        possible_lag = possible_transitions - transitions[j]

        all_possible_lags.extend(possible_lag)
    
all_lags = np.r_[-11:0,1:12]
actual_counts = []
possible_counts = []
lag_crp = []

for lag in all_lags:
    actual_count = int(all_actual_lags.count(lag))
    possible_count = int(all_possible_lags.count(lag))

    actual_counts.append(actual_count)
    possible_counts.append(possible_count)

    lag_crp.append(actual_count / possible_count if possible_count != 0 else 0)


lag_crp_dict = {"actual count":actual_counts, "possible count":possible_counts, "conditional probability":lag_crp}
lag_crp_df = pd.DataFrame.from_dict(lag_crp_dict, orient="index", columns = all_lags)
lag_crp_df
# Out:
#                               -11       -10  -9        -8    -7         -6   \
# actual count             1.000000  2.000000  0.0  1.000000   3.0   2.000000
# possible count           3.000000  6.000000  6.0  7.000000  10.0  12.000000
# conditional probability  0.333333  0.333333  0.0  0.142857   0.3   0.166667
#
#                                -5         -4    -3         -2   ...  \
# actual count              2.000000   1.000000   0.0   1.000000  ...
# possible count           17.000000  14.000000  21.0  22.000000  ...
# conditional probability   0.117647   0.071429   0.0   0.045455  ...
#
#                                 2      3          4     5          6   \
# actual count              9.000000   1.00   4.000000   0.0   2.000000
# possible count           26.000000  20.00  22.000000  16.0  17.000000
# conditional probability   0.346154   0.05   0.181818   0.0   0.117647
#
#                                 7          8         9    10   11
# actual count              2.000000   2.000000  1.000000  0.0  1.0
# possible count           13.000000  12.000000  9.000000  3.0  2.0
# conditional probability   0.153846   0.166667  0.111111  0.0  0.5
#
# [3 rows x 22 columns]

# %%
fig = plt.figure(figsize=(10, 6))
ax = plt.subplot(111)
ax.plot(all_lags[:11], lag_crp[:11], "--ro")
ax.plot(all_lags[11:], lag_crp[11:], "--ro")
plt.xlabel('Lag'); plt.ylabel('Conditional Response Probability')
plt.show()

# %% [markdown]
# # Inter Response Time

# %%
irt= []
for i in range(len(recalled_time)):
    irt.append(recalled_time[i][1])

    for j in range(2, len(recalled_time[i])):
        irt.append(recalled_time[i][j] - recalled_time[i][j-1])

irt_in_sec = np.array(irt)
irt_90 = np.percentile(irt_in_sec, 95)

figure = plt.figure(figsize=(10, 6))
ax = plt.subplot(111)
plt.hist(irt_in_sec, color="r", alpha = 0.7) 
plt.axvline(irt_90, color="k", linestyle="--", label="{} sec".format(round(irt_90,1)))
plt.xlabel('Time(sec)'); plt.ylabel('Count')
plt.legend()
plt.show()

# %% [markdown]
# # Delivery day data (cued recall)

# %%
delivery_days = [0,1,2,3,4]
total_cued_recall_list = []

for day in delivery_days:
    store_list = []
    store_response_dict = {}
    store_time_dict = {}
    store_item_dict = {}

    correct_list= []
    cued_list = []
    cued_time = []

    # loop through the data...
    for row in range(len(data_frame)-2):
        # convert the string format into json format
        report = data_frame[0][row]
        report_dict = json.loads(report)

        # only look at "data" portion for now
        data_dict = report_dict["data"]
    
        # pull out specific day info
        if (data_dict.get("trial number") != None) and (data_dict["trial number"] == day):
            store_name = data_dict.get("store name")
            item_name = data_dict.get("item name")
            store_item_dict[store_name] = item_name

            store = data_dict.get("store displayed")
            if store != None:

                cued_response = data_dict.get("typed response")
                # if no response seen yet...
                if cued_response == None:
                    # store info in dictionaries
                    if store not in store_list:
                        store_list.append(store)
                    store_response_dict[store] = ""
                    store_time_dict[store] = report_dict["time"]
                # if there is a response...
                else:
                    # update relevant dictionaries
                    store_response_dict[store] = cued_response
                    response_time = np.round((report_dict["time"] - store_time_dict[store]) / 1000, 1)
                    store_time_dict[store] = response_time

    for store in store_list:
        correct_list.append(store_item_dict[store])
        cued_list.append(store_response_dict[store])
        time = store_time_dict[store]
        if time > 15.0:
            cued_time.append(0.0)
        else:
            cued_time.append(time)

    cued_recall_dict = {"list of store" : store_list, "correct item" : correct_list,
                   "items recalled" : cued_list, "time recalled": cued_time}
    cued_recall_df = pd.DataFrame.from_dict(cued_recall_dict, orient="index")
    total_cued_recall_list.append(cued_recall_df)

# %%
total_cued_recall_df = pd.concat(total_cued_recall_list, keys=["Day1", "Day2", "Day3", "Day4", "Day5"])
total_cued_recall_df
# Out:
#                                  0              1               2   \
# Day1 list of store             cafe    music store             gym
#      correct item              cups      amplifier    baseball bat
#      items recalled            cups      amplifier    baseball bat
#      time recalled              2.3            2.7             6.1
# Day2 list of store             cafe  grocery store        pizzeria
#      correct item         chocolate            ham       anchovies
#      items recalled       chocolate            ham         anchovy
#      time recalled              2.8            1.6             3.7
# Day3 list of store    jewelry store       pizzeria          bakery
#      correct item           diamond        oregano         muffins
#      items recalled         diamond        oregano         muffins
#      time recalled              3.2            2.6             2.8
# Day4 list of store   hardware store       pizzeria             gym
#      correct item            screws      pizza box  protein shakes
#      items recalled            wire      pizza box   protein shake
#      time recalled              7.1            2.5             3.4
# Day5 list of store          dentist  grocery store       pet store
#      correct item      cotton balls           bags            cage
#      items recalled     cotton ball           bags
#      time recalled              3.1            2.5             0.0
#
#                                  3               4            5   \
# Day1 list of store   clothing store  hardware store  barber shop
#      correct item               tie           bolts     scissors
#      items recalled             tie           bolts     scissors
#      time recalled              1.9             2.5          2.3
# Day2 list of store   hardware store     barber shop    toy store
#      correct item      tape measure            comb     checkers
#      items recalled                      hair spray     checkers
#      time recalled              0.0            14.2          2.5
# Day3 list of store      barber shop     music store    bike shop
#      correct item            towels          guitar   handle bar
#      items recalled           towel                   handle bar
#      time recalled              2.0             0.0          2.7
# Day4 list of store   clothing store       pet store    bike shop
#      correct item           hangers            bird       decals
#      items recalled          jacket             cat
#      time recalled              8.8             5.9          0.0
# Day5 list of store              gym  hardware store         cafe
#      correct item    hand sanitizer           pipes        syrup
#      items recalled  hand sanitizer           pipes        syrup
#      time recalled              4.7             4.8          0.0
#
#                                 6            7                8            9   \
# Day1 list of store   grocery store      florist        bike shop       bakery
#      correct item      blueberries   fertilizer  training wheels        bread
#      items recalled    blueberries   fertilizer   training wheel        sugar
#      time recalled             4.1          3.0              3.8          5.2
# Day2 list of store       pet store  music store   clothing store     pharmacy
#      correct item        fish bowl    saxophone           shorts   nose spray
#      items recalled      fish bowl                        shorts   nose spray
#      time recalled             4.8          0.0             10.2          4.0
# Day3 list of store         florist         cafe    grocery store      dentist
#      correct item          peonies         milk           grapes    mouthwash
#      items recalled        peonies         milk              ham    mouthwash
#      time recalled             2.6          2.7              1.3          3.5
# Day4 list of store      craft shop         cafe           bakery  music store
#      correct item           thread       scones            apron     recorder
#      items recalled         thread       coffee            apron     recorder
#      time recalled             2.1         13.0              2.7          2.3
# Day5 list of store          bakery     pharmacy      barber shop  music store
#      correct item          canolli    ear plugs          shampoo       violin
#      items recalled         canoli                       shampoo       violin
#      time recalled             2.5          0.0              2.3          2.5
#
#                                  10              11
# Day1 list of store         pizzeria         dentist
#      correct item              menu           drill
#      items recalled            menu           drill
#      time recalled              1.7             2.4
# Day2 list of store        bike shop   jewelry store
#      correct item         back pack        sapphire
#      items recalled        backpack        sapphire
#      time recalled              3.1             2.7
# Day3 list of store              gym  clothing store
#      correct item        volleyball         sandals
#      items recalled      volleyball         sandals
#      time recalled              2.9             3.7
# Day4 list of store    grocery store        pharmacy
#      correct item         asparagus     cough syrup
#      items recalled       asparagus     cough syrup
#      time recalled              3.7             6.6
# Day5 list of store   clothing store       toy store
#      correct item         head band  action figures
#      items recalled       head band   action figure
#      time recalled              2.9             3.4

# %% [markdown]
# # Final store and object recall analysis

# %%
#final store & object recall
final_store_recall = []
final_store_time = []
final_object_recall = []
final_object_time = []

for row in range(len(data_frame)-2):
    report = data_frame[0][row]
    report_dict = json.loads(report)

    if report_dict["type"] == "final store recall":
        data = report_dict["data"]
        final_store_recall.append(data["typed response"])
        final_store_time.append(report_dict["time"])

    if report_dict["type"] == "final object recall":
        data = report_dict["data"]
        final_object_recall.append(data["typed response"])
        final_object_time.append(report_dict["time"])

final_store_time[:] = [(time - final_store_time[0]) / 1000 for time in final_store_time]
final_object_time[:] = [(time - final_object_time[0]) / 1000 for time in final_object_time]

final_store_dict = {"final store":final_store_recall,
                     "time recalled":final_store_time}

final_object_dict = {"final object":final_object_recall,
                     "time recalled":final_object_time}

final_store_df = pd.DataFrame.from_dict(final_store_dict, orient="index")
final_object_df = pd.DataFrame.from_dict(final_object_dict, orient="index")

# %%
pd.set_option('display.max_columns', 100)
display(final_store_df)
display(final_object_df)
# Out:
#                      0          1       2          3            4   \
# final store    pharmacy  toy store  bakery  bike shop  music store
# time recalled       0.0     2.9304  4.8952      8.728      11.4434
#
#                            5         6        7              8   \
# final store    clothing store  pizzeria     cafe  jewelry store
# time recalled         13.9249   17.2252  19.2901        23.9043
#
#                           9               10           11          12  \
# final store    grocery store  hardware store  barber shop  craft shop
# time recalled        26.5706         34.3006      38.5984     44.8628
#
#                     13       14         15
# final store    dentist  florist  pet store
# time recalled  46.2118  48.4272    49.9773
#                    0       1       2        3        4          5        6   \
# final object   canoli   apron  muffin     milk    syrup  chocolate     menu
# time recalled     0.0  2.1138   5.463  10.2606  14.7915    16.2416  18.1733
#
#                       7        8        9        10       11       12  \
# final object   pizza box    basil  oregano     menu      ham    grape
# time recalled    20.6068  22.2224  23.9051  25.0546  27.5557  28.9197
#
#                     13         14        15       16       17        18  \
# final object      bags  asparagus  sapphire  diamond   violin  recorder
# time recalled  29.7867    32.0357   40.8306  42.2804  45.1795   46.3953
#
#                       19             20          21              22  \
# final object   amplifier  protein shake  volleyball  hand sanitizer
# time recalled     47.895        52.0109     58.1074         61.1897
#
#                          23             24        25         26         27  \
# final object   baseball bat  action figure  checkers  train set  water gun
# time recalled       70.4355        75.6508   77.8328    81.4663    84.6303
#
#                         28       29          30       31         32  \
# final object   cotton ball  peonies  fertilizer    floss  mouthwash
# time recalled      89.0105   90.777      93.443  95.9918    99.3072
#
#                       33        34          35              36        37  \
# final object   fish bowl  backpack  handle bar  training wheel     pipes
# time recalled   105.5383  107.7209    109.8686        112.0351  117.0178
#
#                      38        39        40       41          42        43  \
# final object    shampoo     bolts  scissors   thread  nose spray  eye drop
# time recalled  118.8153  122.9983  127.5624  128.479    138.2419  142.5415
#
#                         44         45        46        47        48        49  \
# final object   cough syrup  head band       tie   sandals   anchovy  amethyst
# time recalled     147.3705   160.9655  161.6475  163.0813  184.8882  201.4812
#
#                      50
# final object      towel
# time recalled  208.2972
